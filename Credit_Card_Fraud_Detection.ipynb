# %% [markdown]
# ##  Credit Card Fraud Detection (Unsupervised Anomaly Detection)

# %% [markdown]
# ### Data
# Source: https://dacon.io/competitions/official/235930/data
# #### Train Dataset
# * Unlabeled card data
# * Columns:
#     * `id`: card transaction ID
#     * `V1`, `V2`, ... ,`V30` : card features
#
# #### Validation Dataset
# * Labeled card data
# * Used for performance measure only
# * Columns:
#     * `id`: card transaction ID
#     * `V1`, `V2`, ... ,`V30`: card features
#     * `class`: class indicating transcation type (0: normal, 1: fraud)
#
# #### Test Dataset
# * Unlabeled card data
# * Used for final score measurement
# * Columns:
#     * `id`: card transaction ID
#     * `V1`, `V2`, ... ,`V30` : card features
#
# ### Score Measures
# * Evaluated with macro f1-score
# * Public score: measured with 30% of the test data
# * Private score: measured with the remaining 70% of the test data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import pyod

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import f1_score, classification_report, confusion_matrix, precision_recall_fscore_support
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
from pyod.models.auto_encoder import AutoEncoder
import time

pd.set_option('mode.chained_assignment',  None)

# %% [markdown]
# ### Data Loading & EDA

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
val = pd.read_csv('val.csv')

# %%
train.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0   3 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1   4 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2   6 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3   8 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4   9 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 1  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 2  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 3 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 4  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
#
#         V26       V27       V28       V29       V30
# 0 -0.139097 -0.055353 -0.059752  4.983721 -0.994972
# 1 -0.221929  0.062723  0.061458  1.418291 -0.994972
# 2  0.105915  0.253844  0.081080 -0.256131 -0.994960
# 3 -0.051634 -1.206921 -1.085339  0.262698 -0.994901
# 4 -0.384157  0.011747  0.142404  0.994900 -0.994901
#
# [5 rows x 31 columns]

# %%
val.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0  10 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# 1  22  0.962496  0.328461 -0.171479  2.109204  1.129566  1.696038  0.107712
# 2  63  1.145524  0.575068  0.194008  2.598192 -0.092210 -1.044430  0.531588
# 3  69  0.927060 -0.323684  0.387585  0.544474  0.246787  1.650358 -0.427576
# 4  83 -3.005237  2.600138  1.483691 -2.418473  0.306326 -0.824575  2.065426
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.069539 -0.736727  ... -0.633753 -0.120794 -0.385050 -0.069733  0.094199
# 1  0.521502 -1.191311  ...  0.402492 -0.048508 -1.371866  0.390814  0.199964
# 2 -0.241888 -0.896287  ... -0.119703 -0.076510  0.691320  0.633984  0.048741
# 3  0.615371  0.226278  ...  0.079359  0.096632 -0.992569  0.085096  0.377447
# 4 -1.829347  4.009259  ... -0.181268 -0.163747  0.515821  0.136318  0.460054
#
#         V27       V28       V29       V30  Class
# 0  0.246219  0.083076 -0.255991 -0.994878      0
# 1  0.016371 -0.014605  0.168937 -0.994784      0
# 2 -0.053192  0.016251  0.169496 -0.994502      0
# 3  0.036096 -0.005960  0.331307 -0.994467      0
# 4 -0.251259 -1.105751 -0.287012 -0.994373      0
#
# [5 rows x 32 columns]

# %%
test.head()
# Out:
#         ID        V1        V2        V3        V4        V5        V6  \
# 0  AAAA0x1 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1  AAAA0x2  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2  AAAA0x5 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 3  AAAA0x7  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 4  AAAA0xc  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
# 3 -0.005159  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055
# 4  0.470455  0.538247 -0.558895  ...  0.049924  0.238422  0.009130  0.996710
#
#         V25       V26       V27       V28       V29       V30
# 0  0.128539 -0.189115  0.133558 -0.021053  1.783274 -0.994983
# 1  0.167170  0.125895 -0.008983  0.014724 -0.269825 -0.994983
# 2 -0.206010  0.502292  0.219422  0.215153  0.670579 -0.994960
# 3  0.750137 -0.257237  0.034507  0.005168 -0.237686 -0.994937
# 4 -0.767315 -0.492208  0.042472 -0.054337 -0.167819 -0.994866
#
# [5 rows x 31 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113842 entries, 0 to 113841
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      113842 non-null  int64
#  1   V1      113842 non-null  float64
#  2   V2      113842 non-null  float64
#  3   V3      113842 non-null  float64
#  4   V4      113842 non-null  float64
#  5   V5      113842 non-null  float64
#  6   V6      113842 non-null  float64
#  7   V7      113842 non-null  float64
#  8   V8      113842 non-null  float64
#  9   V9      113842 non-null  float64
#  10  V10     113842 non-null  float64
#  11  V11     113842 non-null  float64
#  12  V12     113842 non-null  float64
#  13  V13     113842 non-null  float64
#  14  V14     113842 non-null  float64
#  15  V15     113842 non-null  float64
#  16  V16     113842 non-null  float64
#  17  V17     113842 non-null  float64
#  18  V18     113842 non-null  float64
#  19  V19     113842 non-null  float64
#  20  V20     113842 non-null  float64
#  21  V21     113842 non-null  float64
#  22  V22     113842 non-null  float64
#  23  V23     113842 non-null  float64
#  24  V24     113842 non-null  float64
#  25  V25     113842 non-null  float64
#  26  V26     113842 non-null  float64
#  27  V27     113842 non-null  float64
#  28  V28     113842 non-null  float64
#  29  V29     113842 non-null  float64
#  30  V30     113842 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 26.9 MB

# %%
train.isnull().sum()
# Out:
# ID     0
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# dtype: int64

# %%
train_df = train.drop(['ID'], axis=1)
test_df = test.drop(['ID'], axis=1)
val_df = val.drop(['ID', 'Class'], axis=1)

# %%
train_df.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean        0.000197       0.001289       0.009717      -0.004169
# std         1.951060       1.651064       1.496916       1.412633
# min       -56.407510     -72.715728     -32.454198      -5.600607
# 25%        -0.923479      -0.595602      -0.883877      -0.853728
# 50%         0.012074       0.066390       0.183868      -0.019359
# 75%         1.315373       0.801687       1.037120       0.742208
# max         2.454930      21.467203       4.187811      16.491217
#
#                   V5             V6             V7             V8  \
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean        0.000475       0.005141       0.005769      -0.002451
# std         1.367533       1.330583       1.204111       1.185504
# min       -42.147898     -26.160506     -41.506796     -50.943369
# 25%        -0.689853      -0.766094      -0.552071      -0.209492
# 50%        -0.054060      -0.272436       0.039036       0.020970
# 75%         0.614214       0.405285       0.568750       0.328303
# max        34.801666      23.917837      44.054461      20.007208
#
#                   V9            V10  ...            V21           V22  \
# count  113842.000000  113842.000000  ...  113842.000000  1.138420e+05
# mean       -0.002107       0.005209  ...      -0.001242  4.088347e-07
# std         1.095415       1.071337  ...       0.722001  7.238291e-01
# min       -13.434066     -24.403185  ...     -22.757540 -8.887017e+00
# 25%        -0.647477      -0.533477  ...      -0.229710 -5.402665e-01
# 50%        -0.052157      -0.090810  ...      -0.030281  8.345807e-03
# 75%         0.590705       0.455287  ...       0.186001  5.287508e-01
# max        10.392889      15.331742  ...      27.202839  8.361985e+00
#
#                  V23            V24            V25            V26  \
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean       -0.001317      -0.000884       0.001680      -0.000293
# std         0.636061       0.605854       0.520069       0.480979
# min       -44.807735      -2.824849     -10.295397      -1.855355
# 25%        -0.162180      -0.355582      -0.315470      -0.326160
# 50%        -0.012261       0.040573       0.018278      -0.052815
# 75%         0.147474       0.438225       0.353989       0.240838
# max        22.528412       4.022866       7.519589       3.119295
#
#                  V27            V28            V29            V30
# count  113842.000000  113842.000000  113842.000000  113842.000000
# mean       -0.000234      -0.000508       0.927253       0.116232
# std         0.399505       0.356130       3.412933       0.558161
# min        -9.895244      -9.617915      -0.307413      -0.994972
# 25%        -0.070847      -0.053249      -0.230560      -0.360304
# 50%         0.001502       0.011158      -0.000699      -0.002590
# 75%         0.091279       0.077851       0.768532       0.640653
# max        11.135740      33.847808     180.101027       1.034951
#
# [8 rows x 30 columns]

# %%
val_norm, val_fraud = val['Class'].value_counts()
val_contamination = val_fraud/val_norm
print("정상거래: %d, 사기거래: %d" %(val_norm, val_fraud))
print("비율: %5f" %(val_contamination))
# Out:
# 정상거래: 28432, 사기거래: 30
# 비율: 0.001055

# %% [markdown]
# * Since the true labels in the training data are unknown, we simply assume that it contains the same proportion of fraud transactions as the validation data.

# %%
# Check data distributions
train_df.hist(bins=50, figsize=(15, 15), edgecolor="black")
plt.show()

# %%
# Check boxplots
plt.figure(figsize=(30,5))
sns.boxplot(data=train_df)
plt.show()

# %%
# Correlation table color-coded
def color_(value):
    if value < 0 :
        color = 'red'
    elif value == 1 :
        color = 'blue'
    else:
        color = 'green'
    return 'color: %s' % color
train_df.corr().style.applymap(color_)
# Out:
# <style type="text/css">
# #T_78b9c_row0_col0, #T_78b9c_row1_col1, #T_78b9c_row2_col2, #T_78b9c_row3_col3, #T_78b9c_row4_col4, #T_78b9c_row5_col5, #T_78b9c_row6_col6, #T_78b9c_row7_col7, #T_78b9c_row8_col8, #T_78b9c_row9_col9, #T_78b9c_row10_col10, #T_78b9c_row11_col11, #T_78b9c_row12_col12, #T_78b9c_row13_col13, #T_78b9c_row14_col14, #T_78b9c_row15_col15, #T_78b9c_row16_col16, #T_78b9c_row17_col17, #T_78b9c_row18_col18, #T_78b9c_row19_col19, #T_78b9c_row20_col20, #T_78b9c_row21_col21, #T_78b9c_row22_col22, #T_78b9c_row23_col23, #T_78b9c_row24_col24, #T_78b9c_row25_col25, #T_78b9c_row26_col26, #T_78b9c_row27_col27, #T_78b9c_row28_col28, #T_78b9c_row29_col29 {
#   color: blue;
# }
# #T_78b9c_row0_col1, #T_78b9c_row0_col3, #T_78b9c_row0_col7, #T_78b9c_row0_col10, #T_78b9c_row0_col12, #T_78b9c_row0_col19, #T_78b9c_row0_col20, #T_78b9c_row0_col22, #T_78b9c_row0_col24, #T_78b9c_row0_col26, #T_78b9c_row0_col29, #T_78b9c_row1_col0, #T_78b9c_row1_col2, #T_78b9c_row1_col4, #T_78b9c_row1_col5, #T_78b9c_row1_col6, #T_78b9c_row1_col7, #T_78b9c_row1_col8, #T_78b9c_row1_col9, #T_78b9c_row1_col11, #T_78b9c_row1_col12, #T_78b9c_row1_col13, #T_78b9c_row1_col15, #T_78b9c_row1_col16, #T_78b9c_row1_col17, #T_78b9c_row1_col19, #T_78b9c_row1_col20, #T_78b9c_row1_col21, #T_78b9c_row1_col22, #T_78b9c_row1_col25, #T_78b9c_row1_col26, #T_78b9c_row2_col1, #T_78b9c_row2_col3, #T_78b9c_row2_col7, #T_78b9c_row2_col10, #T_78b9c_row2_col19, #T_78b9c_row2_col21, #T_78b9c_row2_col22, #T_78b9c_row2_col23, #T_78b9c_row2_col24, #T_78b9c_row2_col25, #T_78b9c_row2_col26, #T_78b9c_row3_col0, #T_78b9c_row3_col2, #T_78b9c_row3_col4, #T_78b9c_row3_col5, #T_78b9c_row3_col6, #T_78b9c_row3_col7, #T_78b9c_row3_col8, #T_78b9c_row3_col9, #T_78b9c_row3_col11, #T_78b9c_row3_col12, #T_78b9c_row3_col13, #T_78b9c_row3_col14, #T_78b9c_row3_col15, #T_78b9c_row3_col16, #T_78b9c_row3_col17, #T_78b9c_row3_col18, #T_78b9c_row3_col23, #T_78b9c_row3_col24, #T_78b9c_row3_col25, #T_78b9c_row3_col27, #T_78b9c_row3_col28, #T_78b9c_row4_col1, #T_78b9c_row4_col3, #T_78b9c_row4_col10, #T_78b9c_row4_col12, #T_78b9c_row4_col14, #T_78b9c_row4_col18, #T_78b9c_row4_col21, #T_78b9c_row4_col23, #T_78b9c_row4_col26, #T_78b9c_row4_col29, #T_78b9c_row5_col1, #T_78b9c_row5_col3, #T_78b9c_row5_col7, #T_78b9c_row5_col10, #T_78b9c_row5_col12, #T_78b9c_row5_col14, #T_78b9c_row5_col18, #T_78b9c_row5_col19, #T_78b9c_row5_col20, #T_78b9c_row5_col22, #T_78b9c_row5_col27, #T_78b9c_row5_col28, #T_78b9c_row6_col1, #T_78b9c_row6_col3, #T_78b9c_row6_col7, #T_78b9c_row6_col10, #T_78b9c_row6_col18, #T_78b9c_row6_col19, #T_78b9c_row6_col20, #T_78b9c_row6_col22, #T_78b9c_row6_col24, #T_78b9c_row6_col25, #T_78b9c_row6_col27, #T_78b9c_row6_col28, #T_78b9c_row6_col29, #T_78b9c_row7_col0, #T_78b9c_row7_col1, #T_78b9c_row7_col2, #T_78b9c_row7_col3, #T_78b9c_row7_col5, #T_78b9c_row7_col6, #T_78b9c_row7_col11, #T_78b9c_row7_col12, #T_78b9c_row7_col13, #T_78b9c_row7_col15, #T_78b9c_row7_col16, #T_78b9c_row7_col17, #T_78b9c_row7_col20, #T_78b9c_row7_col21, #T_78b9c_row7_col22, #T_78b9c_row7_col23, #T_78b9c_row7_col25, #T_78b9c_row8_col1, #T_78b9c_row8_col3, #T_78b9c_row8_col10, #T_78b9c_row8_col18, #T_78b9c_row8_col23, #T_78b9c_row8_col25, #T_78b9c_row8_col27, #T_78b9c_row9_col1, #T_78b9c_row9_col3, #T_78b9c_row9_col10, #T_78b9c_row9_col14, #T_78b9c_row9_col18, #T_78b9c_row9_col19, #T_78b9c_row9_col21, #T_78b9c_row9_col23, #T_78b9c_row9_col27, #T_78b9c_row9_col29, #T_78b9c_row10_col0, #T_78b9c_row10_col2, #T_78b9c_row10_col4, #T_78b9c_row10_col5, #T_78b9c_row10_col6, #T_78b9c_row10_col8, #T_78b9c_row10_col9, #T_78b9c_row10_col11, #T_78b9c_row10_col13, #T_78b9c_row10_col14, #T_78b9c_row10_col15, #T_78b9c_row10_col16, #T_78b9c_row10_col17, #T_78b9c_row10_col21, #T_78b9c_row10_col25, #T_78b9c_row11_col1, #T_78b9c_row11_col3, #T_78b9c_row11_col7, #T_78b9c_row11_col10, #T_78b9c_row11_col18, #T_78b9c_row11_col20, #T_78b9c_row11_col21, #T_78b9c_row11_col23, #T_78b9c_row11_col25, #T_78b9c_row11_col27, #T_78b9c_row11_col29, #T_78b9c_row12_col0, #T_78b9c_row12_col1, #T_78b9c_row12_col3, #T_78b9c_row12_col4, #T_78b9c_row12_col5, #T_78b9c_row12_col7, #T_78b9c_row12_col14, #T_78b9c_row12_col15, #T_78b9c_row12_col16, #T_78b9c_row12_col17, #T_78b9c_row12_col21, #T_78b9c_row12_col27, #T_78b9c_row12_col28, #T_78b9c_row13_col1, #T_78b9c_row13_col3, #T_78b9c_row13_col7, #T_78b9c_row13_col10, #T_78b9c_row13_col14, #T_78b9c_row13_col18, #T_78b9c_row13_col20, #T_78b9c_row13_col22, #T_78b9c_row13_col24, #T_78b9c_row13_col26, #T_78b9c_row13_col27, #T_78b9c_row13_col28, #T_78b9c_row14_col3, #T_78b9c_row14_col4, #T_78b9c_row14_col5, #T_78b9c_row14_col9, #T_78b9c_row14_col10, #T_78b9c_row14_col12, #T_78b9c_row14_col13, #T_78b9c_row14_ ...

# %%
# Excluding V29 since it contains outliers 
train_df.drop('V29', axis=1, inplace = True)
test_df.drop('V29', axis=1, inplace = True)
val_df.drop('V29', axis=1, inplace = True)

# %%
g = sns.PairGrid(train_df.iloc[:,:3].sample(600, random_state=42))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Before:')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot);
# source: https://www.kaggle.com/code/robinteuwens/anomaly-detection-with-auto-encoders

# %%
# Normalizing & Standardizing
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])

# Get normalization parameters by fitting to the training data
pipeline.fit(train_df)
# Out:
# Pipeline(steps=[('normalizer', Normalizer()), ('scaler', MinMaxScaler())])

# %%
# Apply
train_df.iloc[:,:] = pipeline.transform(train_df)
test_df.iloc[:,:] = pipeline.transform(test_df)
val_df.iloc[:,:] = pipeline.transform(val_df)

# %%
g = sns.PairGrid(train_df.iloc[:,:3].sample(600, random_state=42))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('After:')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot);

# %% [markdown]
# ## Models
# * Tested 4 models commonly used for anomaly detection
# * Based on the f1 score from the validation dataset, the best performing model out of the 4 was chosen for final prediction.

# %%
# Function for confusion matrix visualization
def plot_confusion_matrix(cm,target_names,title='Confusion matrix',cmap=None,
                          normalize=False):
    import itertools
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
# Source: https://www.kaggle.com/code/drscarlat/compare-6-unsupervised-anomaly-detection-models

# %%
val['Class'].value_counts()
# Out:
# 0    28432
# 1       30
# Name: Class, dtype: int64

# %% [markdown]
# ### Isolation Forest

# %%
# Test inital model
IF = IsolationForest(n_estimators=150, max_samples=len(train_df), contamination = val_contamination, max_features = 1, random_state=77)
IF.fit(train_df)

pred = IF.predict(val_df)
y = val['Class']

pred_if = [1 if i==-1 else 0 for i in pred]
val_score = f1_score(y, pred_if, average='macro')

print("Macro f1 score: %.5f" %(val_score))
print(classification_report(y, pred_if))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Macro f1 score: 0.49900
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.00      0.00      0.00        30
#
#     accuracy                           1.00     28462
#    macro avg       0.50      0.50      0.50     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
CM=confusion_matrix(y, pred_if)
plot_confusion_matrix(CM, 
                      normalize    = False,
                      target_names = ['Normal', 'Fraud'],
                      title        = "IsolationForest Confusion Matrix")

# %% [markdown]
# ### Local Outlier Factor

# %%
# Test inital model
LOF = LocalOutlierFactor(contamination = val_contamination, novelty=True)
LOF.fit(train_df)

pred = LOF.predict(val_df)
y = val['Class'] 

pred_lof = [1 if i==-1 else 0 for i in pred]
val_score = f1_score(y, pred_lof, average='macro')

print("Macro f1 score: %.5f" %(val_score))
print(classification_report(y, pred_lof))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# Macro f1 score: 0.49951
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.00      0.00      0.00        30
#
#     accuracy                           1.00     28462
#    macro avg       0.50      0.50      0.50     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
CM=confusion_matrix(y, pred_lof)
plot_confusion_matrix(CM, 
                      normalize    = False,
                      target_names = ['Normal', 'Fraud'],
                      title        = "LocalOutlierFactor Confusion Matrix")

# %%
# Optimize LOF hyperparameter n_neighbors for best f1

minRE = 1000
maxRE = 1600
    
LofF1 = []

for TryRE in np.arange(minRE, maxRE, 100):
  y = val['Class'] 
  clf = LocalOutlierFactor(n_neighbors=TryRE, contamination = val_contamination, novelty=True)
  clf.fit(train_df)
  y_pred = clf.predict(val_df)
  
  y_pred_lof = [1 if i==-1 else 0 for i in y_pred]
  macro_f1 = f1_score(y, y_pred_lof, average='macro')
  
  print("F1 score on validation", round(macro_f1,5), " with num neighbors ", TryRE)
  LofF1.append([TryRE, round(macro_f1,5)])
    
LofF1df = pd.DataFrame(LofF1, columns = ['NumNeighb', 'F1'])
LofF1df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on validation 0.7537  with num neighbors  1000
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on validation 0.7537  with num neighbors  1100
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on validation 0.7537  with num neighbors  1200
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on validation 0.7537  with num neighbors  1300
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on validation 0.7578  with num neighbors  1400
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# F1 score on validation 0.7537  with num neighbors  1500
#    NumNeighb      F1
# 0       1000  0.7537
# 1       1100  0.7537
# 2       1200  0.7537
# 3       1300  0.7537
# 4       1400  0.7578

# %%
LofF1df.plot.line("NumNeighb","F1")
plt.xlim(1000, 1600)
plt.title("F1 vs NumNeighb")
plt.show()

# %% [markdown]
# ### Robust Covariance (Elliptic Envelope)

# %%
# Test inital model
EE = EllipticEnvelope(support_fraction = 0.994, contamination = val_contamination, random_state = 42)
EE.fit(train_df)

pred = EE.predict(val_df)
y = val['Class'] 

pred_ee = [1 if i==-1 else 0 for i in pred]
val_score_ee = f1_score(y, pred_ee, average='macro')

print("Macro f1 score: %.5f" %(val_score_ee))
print(classification_report(y, pred_ee))
# Out:
# Macro f1 score: 0.91658
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.83      0.83      0.83        30
#
#     accuracy                           1.00     28462
#    macro avg       0.92      0.92      0.92     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
CM=confusion_matrix(y, pred_ee)
plot_confusion_matrix(CM, 
                      normalize    = False,
                      target_names = ['Normal', 'Fraud'],
                      title        = "EllipticEnvelope Confusion Matrix")

# %%
# Optimize EE hyperparameter for best f1

minRE = 0.95
maxRE = 0.99
    
EpsF1 = []

for TryRE in np.arange(minRE, maxRE, 0.01):
  y = val['Class'] 
  cov = EllipticEnvelope(support_fraction = TryRE, contamination = val_contamination)
  cov.fit(train_df)
  y_pred = cov.predict(val_df)
  y_pred_ee = [1 if i==-1 else 0 for i in y_pred]
  macro_f1 = f1_score(y, y_pred_ee, average='macro')
  
  print("F1 score on validation", round(macro_f1,5), " with support_fraction ", TryRE)
  EpsF1.append([TryRE, round(macro_f1,5)])
    
EpsF1df = pd.DataFrame(EpsF1, columns = ['SupFrac', 'F1'])
EpsF1df.head()
# Out:
# F1 score on validation 0.90668  with support_fraction  0.95
# F1 score on validation 0.90668  with support_fraction  0.96
# F1 score on validation 0.91658  with support_fraction  0.97
# F1 score on validation 0.91658  with support_fraction  0.98
# F1 score on validation 0.91658  with support_fraction  0.99
#    SupFrac       F1
# 0     0.95  0.90668
# 1     0.96  0.90668
# 2     0.97  0.91658
# 3     0.98  0.91658
# 4     0.99  0.91658

# %%
EpsF1df.plot.line("SupFrac","F1")
plt.xlim(minRE, maxRE)
plt.title("F1 vs SupFrac")
plt.show()

# %% [markdown]
# * The EE model no longer improves significantly with support fraction values larger than 0.99. After several experiments, I concluded that the model is best with support fraction of 0.994.
# * Setting `assume_cenetered=True` worsens the performance of the model.

# %% [markdown]
# ### AutoEncoder

# %%
atcdr = AutoEncoder(contamination=val_contamination,
                    hidden_neurons =[128,64,32,16,16,32,64,128],
                    validation_size = 0.2,
                    epochs = 20)
atcdr.fit(train_df)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 29)                870
#
#  dropout_4 (Dropout)         (None, 29)                0
#
#  dense_15 (Dense)            (None, 29)                870
#
#  dropout_5 (Dropout)         (None, 29)                0
#
#  dense_16 (Dense)            (None, 128)               3840
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_17 (Dense)            (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_18 (Dense)            (None, 32)                2080
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_19 (Dense)            (None, 16)                528
#
#  dropout_9 (Dropout)         (None, 16)                0
#
#  dense_20 (Dense)            (None, 16)                272
#
#  dropout_10 (Dropout)        (None, 16)                0
#
#  dense_21 (Dense)            (None, 32)                544
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_22 (Dense)            (None, 64)                2112
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 128)               8320
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_24 (Dense)            (None, 29)                3741
#
# =================================================================
# Total params: 31,433
# Trainable params: 31,433
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2847/2847 [==============================] - 10s 3ms/step - loss: 1.1712 - val_loss: 1.0192
# Epoch 2/20
# 2847/2847 [==============================] - 9s 3ms/step - loss: 1.0145 - val_loss: 1.0060
# Epoch 3/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0061 - val_loss: 1.0012
# Epoch 4/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0029 - val_loss: 0.9994
# Epoch 5/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0017 - val_loss: 0.9986
# Epoch 6/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0012 - val_loss: 0.9983
# Epoch 7/20
# 2847/2847 [==============================] - 13s 5ms/step - loss: 1.0009 - val_loss: 0.9981
# Epoch 8/20
# 2847/2847 [==============================] - 10s 4ms/step - loss: 1.0008 - val_loss: 0.9981
# Epoch 9/20
# 2847/2847 [==============================] - 9s 3ms/step - loss: 1.0007 - val_loss: 0.9980
# Epoch 10/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0006 - val_loss: 0.9979
# Epoch 11/20
# 2847/2847 [==============================] - 9s 3ms/step - loss: 1.0006 - val_loss: 0.9979
# Epoch 12/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0006 - val_loss: 0.9979
# Epoch 13/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0006 - val_loss: 0.9979
# Epoch 14/20
# 2847/2847 [==============================] - 10s 3ms/step - loss: 1.0006 - val_loss: 0.9979
# Epoch 15/20
# 2847/2847 [==============================] - 9s 3ms/step - loss: 1.0006 - val_loss: 0.9979
# Epoch 16/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0005 - val_loss: 0.9979
# Epoch 17/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0005 - val_loss: 0.9979
# Epoch 18/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0005 - val_loss: 0.9979
# Epoch 19/20
# 2847/2847 [==============================] - 8s 3ms/step - loss: 1.0005 - val_loss: 0.9979
# Epoch 20/20
# 2847/2847 [==============================] - 10s 4ms/step - loss: 1.0005 - val_loss: 0.9979
# 3558/3558 [==============================] - 4s 1ms/step
# AutoEncoder(batch_size=32, contamination=0.0010551491277433877,
#       dropout_rate=0.2, epochs=20, hidden_activation='relu',
#       hidden_neurons=[128, 64, 32, 16, 16, 32, 64, 128],
#       l2_regularizer=0.1,
#       loss=<function mean_squared_error at 0x7f2032d70ca0>,
#       optimizer='adam', output_activation='sigmoid', preprocessing=True,
#       random_state=None, validation_size=0.2, verbose=1)

# %%
y = val['Class']
pred_ae = atcdr.predict(val_df)
ae_score=f1_score(y, pred_ae, average='macro')

print("Macro f1 score: %.5f" %(ae_score))
print(classification_report(y, pred_ae))
# Out:
# 890/890 [==============================] - 1s 1ms/step
# Macro f1 score: 0.49954
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.00      0.00      0.00        30
#
#     accuracy                           1.00     28462
#    macro avg       0.50      0.50      0.50     28462
# weighted avg       1.00      1.00      1.00     28462

# %% [markdown]
# * Out of the 4 models, Elliptic Envelope predicts with the best validation f1 score

# %% [markdown]
# ## Prediction

# %%
# Final prediction with EE
cov = EllipticEnvelope(support_fraction = 0.994, contamination = val_contamination)
cov.fit(train_df)
pred = cov.predict(test_df)
prediction = [1 if i==-1 else 0 for i in pred]

# %%
submission = pd.read_csv('sample_submission.csv')
submission['Class'] = prediction
submission
# Out:
#              ID  Class
# 0       AAAA0x1      0
# 1       AAAA0x2      0
# 2       AAAA0x5      0
# 3       AAAA0x7      0
# 4       AAAA0xc      0
# ...         ...    ...
# 142498  0x4587f      0
# 142499  0x45880      0
# 142500  0x45884      0
# 142501  0x45885      0
# 142502  0x45887      0
#
# [142503 rows x 2 columns]

# %%
submission['Class'].value_counts()
# Out:
# 0    142205
# 1       298
# Name: Class, dtype: int64

# %%
submission.to_csv('sub.csv', index=False)

# %% [markdown]
# #### FInal scores
# * public: 0.9248241501 / private: 0.9105133393
#
# #### Takeaways
# * Using the same EE model, the score is better off when all 30 features are used for prediction.
# * The score improves when the features are NOT standardized/normalized
# * For this problem, tuning and finding the right kind of model may be more important than data preprocessing.
